# %%
import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

plt.rcParams['font.size'] = 14
plt.rcParams['font.family'] = 'DeJavu Serif'
plt.rcParams['font.serif'] = ['Times New Roman']

# %%
# MNIST veri kümesini indir (sadece training set)
transform = transforms.ToTensor()
mnist_dataset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)

# %%
# İlk 16 örneği al
images, labels = zip(*[mnist_dataset[i] for i in range(16)])


fig, axes = plt.subplots(4, 4, figsize=(8, 9), sharex=True, sharey=True,
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(images[i].reshape(28,28), cmap='binary')
    ax.set_title(f"Etiket: {labels[i]}")
    #ax.axis('off')  # Eksenleri gizle

# PDF olarak kaydet
plt.savefig("mnist.pdf", format='pdf')
plt.show()
